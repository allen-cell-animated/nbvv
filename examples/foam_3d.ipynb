# %%
# %matplotlib inline
import numpy as np
import skimage.io
import matplotlib.pyplot as plt
import nbvv

# %%
image = skimage.io.imread("plateau_border.tif")
image_block = np.expand_dims(image, -1)
print(image_block.shape)
plt.imshow(image_block[0, :, :, 0], cmap = 'bone')
# Out:
# (154, 504, 504, 1)

# %%
nbvv.volshow(image_block[:,:,:,0], spacing=(1.0, 1.0, 2.0))
# Out:
# VolumeWidget(dimensions={'tile_width': 157, 'tile_height': 170, 'rows': 12, 'cols': 13, 'atlas_width': 2041, '…
