# %%
# %pip install matplotlib
# %matplotlib inline
import numpy as np
import skimage.io
import matplotlib.pyplot as plt
import nbvv
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/162.8 kB 660.6 kB/s eta 0:00:01
#      -------------------------- ----------- 112.6/162.8 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    ---------------------- ----------------- 4.3/7.7 MB 90.6 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.7 MB 97.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.7/7.7 MB 81.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/187.5 kB ? eta -:--:--
#    --------------------------------------- 187.5/187.5 kB 11.1 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
# ...

# %%
# you must first unzip plateau_border.tif.zip 
image = skimage.io.imread("plateau_border.tif")
image_block = np.expand_dims(image, -1)
print(image_block.shape)
plt.imshow(image_block[0, :, :, 0], cmap = 'bone')
# Out:
# (154, 504, 504, 1)

# %%
nbvv.volshow(image_block[:,:,:,0], spacing=(1.0, 1.0, 2.0), channel_names=["c0"])
# Out:
# VolumeWidget(dimensions={'name': 'Image0', 'originalSize': [504, 504, 154], 'atlasTileDims': [13, 12], 'volume…
